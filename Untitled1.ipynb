# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sys
from osgeo import gdal, ogr, osr
#import rioxarray as rio

# %%
import rasterio
from rasterio.plot import show
from rasterio.windows import Window
import geopandas as gpd
from shapely.geometry import shape

# %%
import georasters as gr

# %%
import rasterio
import rasterio.features
import rasterio.warp
from IPython.display import clear_output
import multiprocessing
from multiprocessing import Pool

# %%
df = pd.read_csv(r"C:\Users\Antoine Pepin\Documents\Python\age_blocks\Block0_6.csv.gz",compression='gzip')

# %%
df
# Out:
#          Unnamed: 0            0             1    2
# 0                 0 -2297295.524  1.286313e+06   62
# 1                 1 -2297325.524  1.285833e+06   76
# 2                 2 -2297415.524  1.285803e+06   62
# 3                 3 -2297385.524  1.285803e+06   60
# 4                 4 -2297355.524  1.285803e+06  117
# ...             ...          ...           ...  ...
# 1569984     1569984 -2297865.524  1.202103e+06  116
# 1569985     1569985 -2297835.524  1.202103e+06   53
# 1569986     1569986 -2297805.524  1.202103e+06   53
# 1569987     1569987 -2297775.524  1.202103e+06   53
# 1569988     1569988 -2297295.524  1.202103e+06   68
#
# [1569989 rows x 4 columns]

# %%
gfd = gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df['0'],df['1'])).drop(columns=['Unnamed: 0','0','1'],axis=1).rename(columns={'2':'year'})

# %%
gfd
# Out:
#          year                          geometry
# 0          62  POINT (-2297295.524 1286313.110)
# 1          76  POINT (-2297325.524 1285833.110)
# 2          62  POINT (-2297415.524 1285803.110)
# 3          60  POINT (-2297385.524 1285803.110)
# 4         117  POINT (-2297355.524 1285803.110)
# ...       ...                               ...
# 1569984   116  POINT (-2297865.524 1202103.110)
# 1569985    53  POINT (-2297835.524 1202103.110)
# 1569986    53  POINT (-2297805.524 1202103.110)
# 1569987    53  POINT (-2297775.524 1202103.110)
# 1569988    68  POINT (-2297295.524 1202103.110)
#
# [1569989 rows x 2 columns]

# %%
gfd.plot('year',markersize=0.001)
# Out:
# <Axes: >
